# %%
import pandas as pd
import os
file_path = "/opt/test-data/companies.zip"

if not os.path.exists(file_path):
  display(
    f"Error: The file '{file_path}' was not found. Please ensure it is in the same directory."
  )
else:
  df = pd.read_csv(file_path, compression="zip",dtype={"year founded":"Int64"})

  display("--- First 5 rows of the dataset ---")
  display(df.head())

  display("\n--- Dataset Info (data types, missing values) ---")
  display(df.info())

  display("\n--- Statistical Summary of Numerical Features ---")
  display(df.describe())
# Out:
# '--- First 5 rows of the dataset ---'
#    Unnamed: 0                       name         domain  year founded  \
# 0     5872184                        ibm        ibm.com          1911
# 1     4425416  tata consultancy services        tcs.com          1968
# 2       21074                  accenture  accenture.com          1989
# 3     2309813                    us army     goarmy.com          1800
# 4     1558607                         ey         ey.com          1989
#
#                               industry size range  \
# 0  information technology and services     10001+
# 1  information technology and services     10001+
# 2  information technology and services     10001+
# 3                             military     10001+
# 4                           accounting     10001+
#
#                                  locality         country  \
# 0       new york, new york, united states   united states
# 1              bombay, maharashtra, india           india
# ...

# %%
print(df.sample(25).to_csv("/tmp/comp_sample.csv",index=False))
# Out:
# None
